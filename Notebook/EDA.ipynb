# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

import eda_helper_functions

from sklearn.ensemble import IsolationForest

# %% [markdown]
# ## 2. Read the Training Data

# %%
file_path = r"C:\Users\Kashif ahmad\Flight-Prices-Prediction-AWS-Sagemaker\data\train.csv"

train = pd.read_csv(file_path)
train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       11:50:00        90          0.0  In-flight meal not included   4995
# 1       07:40:00      1360          1.0                      No Info   8372
# 2       11:05:00      1555          2.0                      No Info   6117
# 3       22:55:00      1595          1.0                      No Info   7770
# 4       10:45:00      1065          1.0                      No Info   9187
# ..           ...       ...          ...                          ...    ...
# 635     07:45:00       170          0.0                      No Info   4282
# 636     21:05:00       690          1.0                      No Info  13067
# 637     08:50:00       165          0.0                      No Info   4423
# 638     21:00:00       735          1.0                      No Info   7670
# 639     12:00:00       960          1.0  In-flight meal not included  10844
#
# [640 rows x 10 columns]

# %% [markdown]
# ## 2.1 Fixing Data Types

# %%
train.dtypes
# Out:
# airline             object
# date_of_journey     object
# source              object
# destination         object
# dep_time            object
# arrival_time        object
# duration             int64
# total_stops        float64
# additional_info     object
# price                int64
# dtype: object

# %%
train = train.assign(**{
	col: pd.to_datetime(train.loc[:, col], dayfirst=True, format="mixed")
	for col in ["date_of_journey", "dep_time", "arrival_time"]
})

train.dtypes
# Out:
# airline                    object
# date_of_journey    datetime64[ns]
# source                     object
# destination                object
# dep_time           datetime64[ns]
# arrival_time       datetime64[ns]
# duration                    int64
# total_stops               float64
# additional_info            object
# price                       int64
# dtype: object

# %%
train
# Out:
#                airline date_of_journey    source destination  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad
# 1            Air India      2019-05-18     Delhi      Cochin
# 2            Air India      2019-06-12   Kolkata    Banglore
# 3              Vistara      2019-04-01   Kolkata    Banglore
# 4              Vistara      2019-06-06   Kolkata    Banglore
# ..                 ...             ...       ...         ...
# 635           Air Asia      2019-04-12  Banglore       Delhi
# 636        Jet Airways      2019-05-09   Kolkata    Banglore
# 637             Indigo      2019-05-15  Banglore       Delhi
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin
# 639        Jet Airways      2019-05-21   Kolkata    Banglore
#
#                dep_time        arrival_time  duration  total_stops  \
# 0   2024-07-30 10:20:00 2024-07-30 11:50:00        90          0.0
# 1   2024-07-30 09:00:00 2024-07-30 07:40:00      1360          1.0
# 2   2024-07-30 09:10:00 2024-07-30 11:05:00      1555          2.0
# 3   2024-07-30 20:20:00 2024-07-30 22:55:00      1595          1.0
# 4   2024-07-30 17:00:00 2024-07-30 10:45:00      1065          1.0
# ..                  ...                 ...       ...          ...
# 635 2024-07-30 04:55:00 2024-07-30 07:45:00       170          0.0
# 636 2024-07-30 09:35:00 2024-07-30 21:05:00       690          1.0
# 637 2024-07-30 06:05:00 2024-07-30 08:50:00       165          0.0
# 638 2024-07-30 08:45:00 2024-07-30 21:00:00       735          1.0
# 639 2024-07-30 20:00:00 2024-07-30 12:00:00       960          1.0
#
#                  additional_info  price
# 0    In-flight meal not included   4995
# 1                        No Info   8372
# 2                        No Info   6117
# 3                        No Info   7770
# 4                        No Info   9187
# ..                           ...    ...
# 635                      No Info   4282
# 636                      No Info  13067
# 637                      No Info   4423
# 638                      No Info   7670
# 639  In-flight meal not included  10844
#
# [640 rows x 10 columns]

# %% [markdown]
# ## 3. High-level Summary of Data

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   airline          640 non-null    object
#  1   date_of_journey  640 non-null    datetime64[ns]
#  2   source           640 non-null    object
#  3   destination      640 non-null    object
#  4   dep_time         640 non-null    datetime64[ns]
#  5   arrival_time     640 non-null    datetime64[ns]
#  6   duration         640 non-null    int64
#  7   total_stops      640 non-null    float64
#  8   additional_info  640 non-null    object
#  9   price            640 non-null    int64
# dtypes: datetime64[ns](3), float64(1), int64(2), object(4)
# memory usage: 50.1+ KB

# %%
train.describe(include="number")
# Out:
#           duration  total_stops         price
# count   640.000000   640.000000    640.000000
# mean    639.773438     0.792188   9075.418750
# std     502.047906     0.654060   4328.022872
# min      75.000000     0.000000   1965.000000
# 25%     175.000000     0.000000   5636.250000
# 50%     505.000000     1.000000   8372.000000
# 75%     956.250000     1.000000  12386.750000
# max    2565.000000     3.000000  34273.000000

# %%
(
	train
	.assign(total_stops=train["total_stops"].astype(object))
	.describe(include="O")
)
# Out:
#             airline source destination  total_stops additional_info
# count           640    640         640        640.0             640
# unique            8      5           6          4.0               4
# top     Jet Airways  Delhi      Cochin          1.0         No Info
# freq            248    263         263        351.0             488

# %% [markdown]
# ## 4. High-level analysis of Missing Values

# %%
eda_helper_functions.missing_info(train)
# Out:
# Empty DataFrame
# Columns: [count, percentage]
# Index: []

# %% [markdown]
# ## 5. High-level analysis of Outliers

# %%
forest = IsolationForest(n_estimators=10, random_state=42)

# %%
(
	train
	.assign(outlier=forest.fit_predict(
		train
		.drop(columns="price")
		.select_dtypes(include="number")
	))
	.query("outlier == -1")
	# .duration
	# .describe()
)
# Out:
#                airline date_of_journey   source destination  \
# 0          Jet Airways      2019-06-21   Mumbai   Hyderabad
# 1            Air India      2019-05-18    Delhi      Cochin
# 2            Air India      2019-06-12  Kolkata    Banglore
# 3              Vistara      2019-04-01  Kolkata    Banglore
# 4              Vistara      2019-06-06  Kolkata    Banglore
# ..                 ...             ...      ...         ...
# 626           Spicejet      2019-05-09   Mumbai   Hyderabad
# 627          Air India      2019-03-21    Delhi      Cochin
# 630          Air India      2019-05-12  Kolkata    Banglore
# 632        Jet Airways      2019-03-24  Kolkata    Banglore
# 633  Multiple Carriers      2019-03-06    Delhi      Cochin
#
#                dep_time        arrival_time  duration  total_stops  \
# 0   2024-07-30 10:20:00 2024-07-30 11:50:00        90          0.0
# 1   2024-07-30 09:00:00 2024-07-30 07:40:00      1360          1.0
# 2   2024-07-30 09:10:00 2024-07-30 11:05:00      1555          2.0
# 3   2024-07-30 20:20:00 2024-07-30 22:55:00      1595          1.0
# 4   2024-07-30 17:00:00 2024-07-30 10:45:00      1065          1.0
# ..                  ...                 ...       ...          ...
# 626 2024-07-30 05:45:00 2024-07-30 07:15:00        90          0.0
# 627 2024-07-30 19:45:00 2024-07-30 19:15:00      1410          2.0
# 630 2024-07-30 10:00:00 2024-07-30 01:20:00       920          2.0
# 632 2024-07-30 21:10:00 2024-07-30 22:35:00      1525          1.0
# 633 2024-07-30 15:05:00 2024-07-30 01:35:00       630          2.0
#
#                   additional_info  price  outlier
# 0     In-flight meal not included   4995       -1
# 1                         No Info   8372       -1
# 2                         No Info   6117       -1
# 3                         No Info   7770       -1
# 4                         No Info   9187       -1
# ..                            ...    ...      ...
# 626  No check-in baggage included   1965       -1
# 627                       No Info   8236       -1
# 630                       No Info  13243       -1
# 632   In-flight meal not included  10031       -1
# 633                       No Info  21483       -1
#
# [272 rows x 11 columns]

# %% [markdown]
# ## 6. Pair Plots

# %%
eda_helper_functions.pair_plots(train)
# Out:
# <h2>Pair Plots</h2>

# %% [markdown]
# ## 7. Correlation Analysis

# %%
eda_helper_functions.cramersV_heatmap(train)

# %% [markdown]
# ## 8. Detailed Analysis

# %%
train.columns
# Out:
# Index(['airline', 'date_of_journey', 'source', 'destination', 'dep_time',
#        'arrival_time', 'duration', 'total_stops', 'additional_info', 'price'],
#       dtype='object')

# %% [markdown]
# ## 8.1 airline

# %%
train.airline
# Out:
# 0            Jet Airways
# 1              Air India
# 2              Air India
# 3                Vistara
# 4                Vistara
#              ...
# 635             Air Asia
# 636          Jet Airways
# 637               Indigo
# 638    Multiple Carriers
# 639          Jet Airways
# Name: airline, Length: 640, dtype: object

# %%
eda_helper_functions.cat_summary(train, "airline")
# Out:
# <h2>airline</h2>
# <h3>Quick Glance:</h3>
# 0            Jet Airways
# 1              Air India
# 2              Air India
# 3                Vistara
# 4                Vistara
#              ...
# 635             Air Asia
# 636          Jet Airways
# 637               Indigo
# 638    Multiple Carriers
# 639          Jet Airways
# Name: airline, Length: 640, dtype: object
# <h3>Meta-data:</h3>
# Data Type      : object
# Cardinality    : 8 categories
# Missing Data   : 0 rows (0.00 %)
# Available Data : 640 / 640 rows
# <h3>Summary:</h3>
#
# count           640
# unique            8
# top     Jet Airways
# freq            248
# <h3>Categories Distribution:</h3>
#                    count  percentage
# category
# Jet Airways          248    0.387500
# Indigo               115    0.179688
# Air India            102    0.159375
# Multiple Carriers     68    0.106250
# Spicejet              40    0.062500
# Vistara               36    0.056250
# Air Asia              18    0.028125
# Goair                 13    0.020313

# %%
eda_helper_functions.cat_univar_plots(train, "airline")
# Out:
# <h2>Univariate Analysis of airline</h2>
# <h3></h3>

# %%
eda_helper_functions.cat_univar_plots(train, "airline", show_wordcloud=False, k=3)
# Out:
# <h2>Univariate Analysis of airline</h2>
# <h3></h3>

# %%
eda_helper_functions.num_cat_bivar_plots(
	data=train,
	num_var="price",
	cat_var="airline"
)
# Out:
# <h2>Bi-variate Analysis between airline and price</h2>
# <h3></h3>

# %%
eda_helper_functions.num_cat_hyp_testing(train, "price", "airline")
# Out:
# <h2>Hypothesis Test for Association between price and airline</h2>
# <h3>ANOVA Test</h3>
# - Significance Level   : 5.0%
# - Null Hypothesis      : The groups have similar population mean
# - Alternate Hypothesis : The groups don't have similar population mean
# - Test Statistic       : 42.46553777098078
# - p-value              : 3.970400260466922e-49
# - Since p-value is less than 0.05, we Reject the Null Hypothesis at 5.0% significance level
# - CONCLUSION: The variables price and airline are associated to each other
# <h3>Kruskal-Wallis Test</h3>
# - Significance Level   : 5.0%
# - Null Hypothesis      : The groups have similar population median
# - Alternate Hypothesis : The groups don't have similar population median
# - Test Statistic       : 247.4640193359857
# - p-value              : 9.600459786744093e-50
# - Since p-value is less than 0.05, we Reject the Null Hypothesis at 5.0% significance level
# - CONCLUSION: The variables price and airline are associated to each other

# %%
airline_grid = sns.FacetGrid(
	data=train,
	col="destination",
	col_wrap=3,
	height=4,
	aspect=1.2,
	sharey=True
)

airline_grid.map(sns.barplot, "airline", "price", order=train.airline.unique())

for ax in airline_grid.axes[3:]:
	eda_helper_functions.rotate_xlabels(ax)

# %% [markdown]
# ## 8.2 date_of_journey

# %%
train.date_of_journey
# Out:
# 0     2019-06-21
# 1     2019-05-18
# 2     2019-06-12
# 3     2019-04-01
# 4     2019-06-06
#          ...
# 635   2019-04-12
# 636   2019-05-09
# 637   2019-05-15
# 638   2019-05-15
# 639   2019-05-21
# Name: date_of_journey, Length: 640, dtype: datetime64[ns]

# %%
eda_helper_functions.dt_univar_plots(
	data=train,
	var="date_of_journey",
	target="price"
)
# Out:
# <h3>Univariate plots of date_of_journey</h3>

# %%
(
	train
	.groupby(pd.Grouper(key="date_of_journey", freq="M"))
	.price.mean()
	.to_frame()
	.set_axis(["March", "April", "May", "June"], axis=0)
	.rename_axis(index="month")
	.plot(
		kind="bar",
		figsize=(8, 4),
		edgecolor="black"
	)
)

ax = plt.gca()
eda_helper_functions.rotate_xlabels(ax)

# %%
(
	train
	.groupby(pd.Grouper(key="date_of_journey", freq="W"))
	.price.mean()
	.to_frame()
	.rename_axis(index="week")
	.plot(
		kind="bar",
		figsize=(8, 4),
		edgecolor="black"
	)
)

ax = plt.gca()
eda_helper_functions.rotate_xlabels(ax)

# %%
(
	train
	.groupby([pd.Grouper(key="date_of_journey", freq="M"), "source"])
	.price.mean()
	.unstack(fill_value=0)
	.set_axis(["March", "April", "May", "June"], axis=0)
	.rename_axis(index="month")
	.plot(
		kind="bar",
		figsize=(12, 4),
		edgecolor="black"
	)
)

ax = plt.gca()

ax.legend(
	loc="upper left",
	bbox_to_anchor=(1, 1)
)

eda_helper_functions.rotate_xlabels(ax)

# %% [markdown]
# ## 8.3 dep_time

# %%
train.dep_time
# Out:
# 0     2024-07-30 10:20:00
# 1     2024-07-30 09:00:00
# 2     2024-07-30 09:10:00
# 3     2024-07-30 20:20:00
# 4     2024-07-30 17:00:00
#               ...
# 635   2024-07-30 04:55:00
# 636   2024-07-30 09:35:00
# 637   2024-07-30 06:05:00
# 638   2024-07-30 08:45:00
# 639   2024-07-30 20:00:00
# Name: dep_time, Length: 640, dtype: datetime64[ns]

# %%
eda_helper_functions.dt_univar_plots(train, "dep_time", "price")
# Out:
# <h3>Univariate plots of dep_time</h3>

# %%
(
	train
	.assign(dep_time=lambda df_: (
		np.select([df_.dep_time.dt.hour.between(4, 12, inclusive="left"),
				   df_.dep_time.dt.hour.between(12, 16, inclusive="left"),
				   df_.dep_time.dt.hour.between(16, 20, inclusive="left")],
				  ["morning", "afternoon", "evening"],
				  default="night")
	))
	.pipe(eda_helper_functions.num_cat_bivar_plots, "price", "dep_time")
)
# Out:
# <h2>Bi-variate Analysis between dep_time and price</h2>
# <h3></h3>

# %% [markdown]
# ## 8.4 duration

# %%
train.duration
# Out:
# 0        90
# 1      1360
# 2      1555
# 3      1595
# 4      1065
#        ...
# 635     170
# 636     690
# 637     165
# 638     735
# 639     960
# Name: duration, Length: 640, dtype: int64

# %%
eda_helper_functions.num_summary(train, "duration")
# Out:
# <h2>duration</h2>
# <h3>Quick Glance:</h3>
# 0        90
# 1      1360
# 2      1555
# 3      1595
# 4      1065
#        ...
# 635     170
# 636     690
# 637     165
# 638     735
# 639     960
# Name: duration, Length: 640, dtype: int64
# <h3>Meta-data:</h3>
# Data Type      : int64
# Missing Data   : 0 rows (0.00 %)
# Available Data : 640 / 640 rows
# <h3>Percentiles:</h3>
#               value
# percentile
# 0             75.00
# 5             90.00
# 10           150.00
# 25           175.00
# 50           505.00
# 75           956.25
# 90          1456.50
# 95          1610.25
# 99          1795.00
# 100         2565.00
# <h3>Central Tendancy:</h3>
#                          value
# mean                639.773438
# trimmed mean (5%)   609.296875
# trimmed mean (10%)  581.650391
# median              505.000000
# <h3>Measure of Spread:</h3>
#                        value
# var            252052.100389
# std               502.047906
# IQR               781.250000
# mad               335.000000
# coef_variance       0.784728
# <h3>Skewness and Kurtosis:</h3>
#              value
# skewness  0.817873
# kurtosis -0.304506
# <h3>Hypothesis Testing for Normality:</h3>
# <h4>Shapiro-Wilk Test:</h4>
# Significance Level   : 0.05
# Null Hypothesis      : The data is normally distributed
# Alternate Hypothesis : The data is not normally distributed
# p-value              : 4.7808399310111896e-21
# Test Statistic       : 0.8889472939643862
# - Since p-value is less than alpha (0.05), we Reject the Null Hypothesis at 5.0% significance level
# - CONCLUSION: We conclude that the data sample is not normally distributed
# <h4>Anderson-Darling Test:</h4>
# Significance Level   : 0.05
# Null Hypothesis      : The data is normally distributed
# Alternate Hypothesis : The data is not normally distributed
# Critical Value       : 0.782
# Test Statistic       : 23.671347917330877
# - Since the Test-statistic is greater than Critical Value, we Reject the Null Hypothesis at 5.0% significance level
# - CONCLUSION: We conclude that the data sample is not normally distributed

# %%
train.duration.quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    175.00
# 0.50    505.00
# 0.75    956.25
# Name: duration, dtype: float64

# %%
eda_helper_functions.num_univar_plots(train, "duration")
# Out:
# <h2>Univariate Analysis of duration</h2>
# <h3></h3>

# %%
eda_helper_functions.num_bivar_plots(
	train,
	"duration",
	"price",
	hexbin_kwargs=dict(
		yscale="log",
		gridsize=20,
		cmap="Blues"
	)
)
# Out:
# <h2>Bi-variate Analysis between duration and price</h2>
# <h3></h3>

# %%
eda_helper_functions.num_num_hyp_testing(train, "price", "duration")
# Out:
# <h2>Hypothesis Test for Association between price and duration</h2>
# <h3>Pearson Test</h3>
# - Significance Level   : 5.0%
# - Null Hypothesis      : The samples are uncorrelated
# - Alternate Hypothesis : The samples are correlated
# - Test Statistic       : 0.5542220697543216
# - p-value              : 8.234740030804429e-53
# - Since p-value is less than 0.05, we Reject the Null Hypothesis at 5.0% significance level
# - CONCLUSION: The variables price and duration are correlated
# <h3>Spearman Test</h3>
# - Significance Level   : 5.0%
# - Null Hypothesis      : The samples are uncorrelated
# - Alternate Hypothesis : The samples are correlated
# - Test Statistic       : 0.7020165273730767
# - p-value              : 3.954255142414078e-96
# - Since p-value is less than 0.05, we Reject the Null Hypothesis at 5.0% significance level
# - CONCLUSION: The variables price and duration are correlated

# %%
duration_grid = sns.FacetGrid(
	data=train,
	col="source",
	hue="total_stops",
	sharey=True
)

duration_grid.map(sns.scatterplot, "duration", "price")

duration_grid.add_legend()

# %%
duration_grid = sns.FacetGrid(
	data=train,
	col="source",
	row="additional_info",
	hue="total_stops",
	sharey=True
)

duration_grid.map(sns.scatterplot, "duration", "price")

duration_grid.add_legend()

# %%
eda_helper_functions.get_iqr_outliers(train, "duration")
# Out:
# <h3>duration - IQR Limits:</h3>
# Lower Limit : -996.875
# Upper Limit : 2128.125
#          airline date_of_journey source destination            dep_time  \
# 377  Jet Airways      2019-03-06  Delhi      Cochin 2024-07-30 16:50:00
# 294    Air India      2019-03-21  Delhi      Cochin 2024-07-30 06:50:00
# 284  Jet Airways      2019-03-21  Delhi      Cochin 2024-07-30 09:40:00
#
#            arrival_time  duration  total_stops additional_info  price
# 377 2024-07-30 04:25:00      2135          2.0         No Info  19907
# 294 2024-07-30 19:15:00      2185          2.0         No Info  10756
# 284 2024-07-30 04:25:00      2565          2.0         No Info  12819

# %% [markdown]
# ## 8.5 additional_info

# %%
eda_helper_functions.cat_summary(train, "additional_info")
# Out:
# <h2>additional_info</h2>
# <h3>Quick Glance:</h3>
# 0      In-flight meal not included
# 1                          No Info
# 2                          No Info
# 3                          No Info
# 4                          No Info
#                   ...
# 635                        No Info
# 636                        No Info
# 637                        No Info
# 638                        No Info
# 639    In-flight meal not included
# Name: additional_info, Length: 640, dtype: object
# <h3>Meta-data:</h3>
# Data Type      : object
# Cardinality    : 4 categories
# Missing Data   : 0 rows (0.00 %)
# Available Data : 640 / 640 rows
# <h3>Summary:</h3>
#
# count       640
# unique        4
# top     No Info
# freq        488
# <h3>Categories Distribution:</h3>
#                               count  percentage
# category
# No Info                         488    0.762500
# In-flight meal not included     136    0.212500
# No check-in baggage included     15    0.023438
# 1 Long layover                    1    0.001563

# %%
eda_helper_functions.cat_univar_plots(train, "additional_info")
# Out:
# <h2>Univariate Analysis of additional_info</h2>
# <h3></h3>

# %%
eda_helper_functions.num_cat_bivar_plots(train, "price", "additional_info")
# Out:
# <h2>Bi-variate Analysis between additional_info and price</h2>
# <h3></h3>

# %%
# convertion additional_info into a binary feature for analysis

(
	train
	.assign(additional_info=(
		train
		.additional_info
		.pipe(lambda ser: np.where(ser.eq("No Info"), "no", "yes"))
	))
	.pipe(eda_helper_functions.num_cat_bivar_plots, "price", "additional_info")
)
# Out:
# <h2>Bi-variate Analysis between additional_info and price</h2>
# <h3></h3>

# %% [markdown]
# #### -additional_info has severely rare categories
# #### -Converted it into a binary feature for further analysis

# %% [markdown]
# ## 9. Automated EDA
